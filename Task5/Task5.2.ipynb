# %%
import numpy as np

# %%
k = 3
T = 300
Episodes = 100

# %%
def uniform_initialization(mu_range=(-1, 1), sigma_range=(0.2, 1.2)):
    mus = np.random.uniform(mu_range[0], mu_range[1], k)
    sigmas = np.random.uniform(sigma_range[0], sigma_range[1], k)
    return mus, sigmas

def run_experiments(strategies, T=300):
    results = {strategy: [] for strategy in strategies}
    for strategy in strategies:
        for e in range(Episodes):
            error = run_prediction_bandit(strategy, e+1)
            results[strategy].append(error)
    return results

def run_prediction_bandit(strategy, e, T1=100):
    mus, sigmas = uniform_initialization()
    predictions = []
    errors = []
    actions = []
    observations = {i: [] for i in range(k)}

    for t in range(T):
        if strategy == 'random':
            if t < T1:
                action = (t % 3)
            else:
                min_std = 10
                min_std_action = 0
                for action in range(k):
                    if min_std > np.std(observations[action]):
                        min_std = np.std(observations[action])
                        min_std_action = action
                action = min_std_action
            prediction = np.mean(observations[action]) if observations[action] else 0
        else:
            print("Not yet implemented")
        observation = np.random.normal(mus[action], sigmas[action])
        error = abs(observation - prediction)
        predictions.append(prediction)
        errors.append(error)
        actions.append(action)
        observations[action].append(observation)
    print(f"Error for episode {e} : {sum(errors)}")
    print('-'*60)

# %%
strategies = ['random']
experiment_results = run_experiments(strategies)
# Out:
# Error for episode 1 : 206.19187557383327
# ------------------------------------------------------------
# Error for episode 2 : 193.49437289121013
# ------------------------------------------------------------
# Error for episode 3 : 178.95505020355643
# ------------------------------------------------------------
# Error for episode 4 : 119.58810418013128
# ------------------------------------------------------------
# Error for episode 5 : 144.0540903450474
# ------------------------------------------------------------
# Error for episode 6 : 175.40187901778765
# ------------------------------------------------------------
# Error for episode 7 : 136.7214407886897
# ------------------------------------------------------------
# Error for episode 8 : 139.47109623347228
# ------------------------------------------------------------
# Error for episode 9 : 94.67531467979605
# ------------------------------------------------------------
# Error for episode 10 : 79.20113599134923
# ------------------------------------------------------------
# Error for episode 11 : 108.24609063574557
# ------------------------------------------------------------
# Error for episode 12 : 101.2475103708012
# ------------------------------------------------------------
# Error for episode 13 : 128.42672757461497
# ------------------------------------------------------------
# Error for episode 14 : 143.44426660364195
# ------------------------------------------------------------
# Error for episode 15 : 90.95471495780625
# ------------------------------------------------------------
# Error for episode 16 : 85.08984233242455
# ------------------------------------------------------------
# Error for episode 17 : 97.48924212316568
# ------------------------------------------------------------
# Error for episode 18 : 202.01163141935055
# ------------------------------------------------------------
# Error for episode 19 : 106.94813190070737
# ------------------------------------------------------------
# Error for episode 20 : 175.29603455598706
# ------------------------------------------------------------
# Error for episode 21 : 113.54337938793171
# ------------------------------------------------------------
# Error for episode 22 : 106.29695500728094
# ------------------------------------------------------------
# Error for episode 23 : 98.99643351517055
# ------------------------------------------------------------
# Error for episode 24 : 132.03054986143354
# ------------------------------------------------------------
# Error for episode 25 : 225.40602813939887
# ------------------------------------------------------------
# Error for episode 26 : 172.02166860301222
# ------------------------------------------------------------
# Error for episode 27 : 86.43824617859882
# ------------------------------------------------------------
# Error for episode 28 : 86.50732922334466
# ------------------------------------------------------------
# Error for episode 29 : 119.40893496360258
# ------------------------------------------------------------
# Error for episode 30 : 111.80706699312225
# ------------------------------------------------------------
# Error for episode 31 : 78.61979608465673
# ------------------------------------------------------------
# Error for episode 32 : 110.62636781329834
# ------------------------------------------------------------
# Error for episode 33 : 196.4594373466194
# ------------------------------------------------------------
# Error for episode 34 : 93.6442939973188
# ------------------------------------------------------------
# Error for episode 35 : 255.7041290003357
# ------------------------------------------------------------
# Error for episode 36 : 86.43631481854996
# ------------------------------------------------------------
# Error for episode 37 : 94.43840022711525
# ------------------------------------------------------------
# Error for episode 38 : 107.18900562907577
# ------------------------------------------------------------
# Error for episode 39 : 101.83778488566595
# ------------------------------------------------------------
# Error for episode 40 : 84.42082757452914
# ------------------------------------------------------------
# Error for episode 41 : 188.5191708203103
# ------------------------------------------------------------
# Error for episode 42 : 117.07554574523857
# ------------------------------------------------------------
# Error for episode 43 : 86.1190142288184
# ------------------------------------------------------------
# Error for episode 44 : 113.56783433575752
# ------------------------------------------------------------
# Error for episode 45 : 132.18921710929166
# ------------------------------------------------------------
# Error for episode 46 : 192.33516132134173
# ------------------------------------------------------------
# Error for episode 47 : 277.8058763847055
# ------------------------------------------------------------
# Error for episode 48 : 96.75279396089653
# ------------------------------------------------------------
# Error for episode 49 : 86.09610148579894
# ------------------------------------------------------------
# Error for episode 50 : 114.08119288555093
# ------------------------------------------------------------
# Error for episode 51 : 158.14727089987238
# ------------------------------------------------------------
# Error for episode 52 : 249.34747855101676
# ------------------------------------------------------------
# Error for episode 53 : 235.13365395305024
# ------------------------------------------------------------
# Error for episode 54 : 95.02809172557107
# ------------------------------------------------------------
# Error for episode 55 : 195.6321686326549
# ------------------------------------------------------------
# Error for episode 56 : 139.31317218426597
# ------------------------------------------------------------
# Error for episode 57 : 81.5722783774402
# ------------------------------------------------------------
# Error for episode 58 : 92.90374357015848
# ------------------------------------------------------------
# Error for episode 59 : 103.25917458382565
# ------------------------------------------------------------
# Error for episode 60 : 95.40189695116652
# ------------------------------------------------------------
# Error for episode 61 : 95.19577965536956
# ------------------------------------------------------------
# Error for episode 62 : 88.11992680444648
# ------------------------------------------------------------
# Error for episode 63 : 183.4243702306956
# ------------------------------------------------------------
# Error for episode 64 : 215.50691717443195
# ------------------------------------------------------------
# Error for episode 65 : 161.1877143515967
# ------------------------------------------------------------
# Error for episode 66 : 147.9239283157992
# ------------------------------------------------------------
# Error for episode 67 : 71.51979773539973
# ------------------------------------------------------------
# Error for episode 68 : 193.49634914041428
# ------------------------------------------------------------
# Error for episode 69 : 121.78256455108226
# ------------------------------------------------------------
# Error for episode 70 : 110.92389673930384
# ------------------------------------------------------------
# Error for episode 71 : 111.64561621375067
# ------------------------------------------------------------
# Error for episode 72 : 92.01546092410051
# ------------------------------------------------------------
# Error for episode 73 : 87.49133174815152
# ------------------------------------------------------------
# Error for episode 74 : 112.15849518147665
# ------------------------------------------------------------
# Error for episode 75 : 179.0656624495407
# ------------------------------------------------------------
# Error for episode 76 : 107.3660111433845
# ------------------------------------------------------------
# Error for episode 77 : 222.64410670204938
# ------------------------------------------------------------
# Error for episode 78 : 134.9207138320294
# ------------------------------------------------------------
# Error for episode 79 : 122.93442479506334
# ------------------------------------------------------------
# Error for episode 80 : 162.53145719272814
# ------------------------------------------------------------
# Error for episode 81 : 124.77196547323348
# ------------------------------------------------------------
# Error for episode 82 : 111.65147880688751
# ------------------------------------------------------------
# Error for episode 83 : 114.61117216216763
# ------------------------------------------------------------
# Error for episode 84 : 138.17512979090336
# ------------------------------------------------------------
# Error for episode 85 : 86.64963292482277
# ------------------------------------------------------------
# Error for episode 86 : 159.38654532381236
# ------------------------------------------------------------
# Error for episode 87 : 153.45257068855253
# ------------------------------------------------------------
# Error for episode 88 : 101.65072086738195
# ------------------------------------------------------------
# Error for episode 89 : 120.10509928223627
# ------------------------------------------------------------
# Error for episode 90 : 165.7939830358282
# ------------------------------------------------------------
# Error for episode 91 : 159.94883422676875
# ------------------------------------------------------------
# Error for episode 92 : 90.89925533632533
# ------------------------------------------------------------
# Error for episode 93 : 86.49867104792622
# ------------------------------------------------------------
# Error for episode 94 : 101.7194511716118
# ------------------------------------------------------------
# Error for episode 95 : 144.0147217093733
# ------------------------------------------------------------
# Error for episode 96 : 116.14528830565989
# ------------------------------------------------------------
# Error for episode 97 : 214.92578069915118
# ------------------------------------------------------------
# Error for episode 98 : 76.91352647838052
# ------------------------------------------------------------
# Error for episode 99 : 122.50909330833817
# ------------------------------------------------------------
# Error for episode 100 : 111.07753131352835
# ------------------------------------------------------------
